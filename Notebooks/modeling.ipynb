# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filepath = "../data/raw/customer_data.csv"
df = pd.read_csv(filepath)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.describe(include='all')
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7043   7043    7043.000000    7043       7043  7043.000000
# unique        7043      2            NaN       2          2          NaN
# top     7590-VHVEG   Male            NaN      No         No          NaN
# freq             1   3555            NaN    3641       4933          NaN
# mean           NaN    NaN       0.162147     NaN        NaN    32.371149
# std            NaN    NaN       0.368612     NaN        NaN    24.559481
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
train_vl_df,test_df = train_test_split(df,test_size= 0.2,random_state= 42)
train_df,val_df = train_test_split(train_vl_df,test_size = 0.2,random_state = 45)

# %%
train_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3514  6993-YCOBK    Male              0     Yes        Yes      60
# 1376  3164-AALRN    Male              0      No         No       5
# 3980  8868-WOZGU    Male              0      No         No      28
# 4697  0129-KPTWJ    Male              0     Yes         No      72
# 6455  2478-EEWWM    Male              0     Yes         No      59
# ...          ...     ...            ...     ...        ...     ...
# 1318  1907-YLNYW    Male              0      No         No       8
# 2589  7576-OYWBN    Male              1      No         No       3
# 1092  8590-YFFQO    Male              0     Yes         No      70
# 5569  0013-EXCHZ  Female              1     Yes         No       3
# 5920  9355-NPPFS  Female              1      No         No      26
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 3514          Yes               Yes     Fiber optic            Yes  ...
# ...

# %%
test_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
# ...          ...     ...            ...     ...        ...     ...
# 6366  2845-KDHVX  Female              0     Yes         No      64
# 315   5027-YOCXN    Male              0     Yes        Yes      51
# 2439  8884-MRNSU    Male              0     Yes        Yes      17
# 5002  0567-XRHCU  Female              0     Yes        Yes      69
# 1161  5868-CZJDR    Male              0      No        Yes       1
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 185            No  No phone service             DSL                   No  ...
# ...

# %%
val_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6698  6906-MPARY    Male              0      No         No      40
# 624   1009-IRMNA  Female              0      No         No       7
# 5388  5515-IDEJJ    Male              0     Yes        Yes       1
# 4053  7446-YPODE    Male              1      No         No      11
# 4237  6715-OFDBP    Male              0      No         No       5
# ...          ...     ...            ...     ...        ...     ...
# 365   1010-DIAUQ    Male              0      No         No       5
# 6407  6728-CZFEI  Female              0      No         No      15
# 5222  6854-EXGSF  Female              0      No         No       8
# 5189  6907-FLBER    Male              0      No         No       1
# 1162  9359-UGBTK  Female              0      No         No      67
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 6698          Yes            No     Fiber optic                   No  ...
# ...

# %%
input_cols = list(train_df.columns)[1:-1]
traget_col = 'Churn'

# %%
traget_col
# Out:
# 'Churn'

# %%
train_inputs = train_df[input_cols].copy()
train_targets = train_df[traget_col].copy()

# %%
train_targets
# Out:
# 3514     No
# 1376    Yes
# 3980    Yes
# 4697     No
# 6455     No
#        ...
# 1318     No
# 2589    Yes
# 1092     No
# 5569    Yes
# 5920     No
# Name: Churn, Length: 4507, dtype: object

# %%
val_inputs = val_df[input_cols].copy()
val_targets = val_df[traget_col].copy()

# %%
test_inputs = test_df[input_cols].copy()
test_targets = test_df[traget_col].copy()

# %%
numeric_cols = train_inputs.select_dtypes(include=np.number).columns.tolist()
categorical_cols = train_inputs.select_dtypes(include=np.object_).columns.tolist()

# %%
train_inputs[numeric_cols].describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    4507.000000  4507.000000     4507.000000   4499.000000
# mean        0.163523    32.499667       64.929321   2295.752434
# std         0.369884    24.456846       30.018424   2260.377944
# min         0.000000     0.000000       18.400000     18.800000
# 25%         0.000000     9.000000       36.350000    415.925000
# 50%         0.000000    29.000000       70.600000   1414.650000
# 75%         0.000000    56.000000       89.900000   3803.050000
# max         1.000000    72.000000      118.600000   8594.400000

# %%
train_inputs[categorical_cols].nunique()
# Out:
# gender              2
# Partner             2
# Dependents          2
# PhoneService        2
# MultipleLines       3
# InternetService     3
# OnlineSecurity      3
# OnlineBackup        3
# DeviceProtection    3
# TechSupport         3
# StreamingTV         3
# StreamingMovies     3
# Contract            3
# PaperlessBilling    2
# PaymentMethod       4
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')

# %%
imputer.fit(df[numeric_cols])
# Out:
# SimpleImputer()

# %%
list(imputer.statistics_)
# Out:
# [np.float64(0.1621468124378816),
#  np.float64(32.37114865824223),
#  np.float64(64.76169246059918),
#  np.float64(2283.3004408418656)]

# %%
train_inputs[numeric_cols] = imputer.transform(train_inputs[numeric_cols])
val_inputs[numeric_cols] = imputer.transform(val_inputs[numeric_cols])
test_inputs[numeric_cols] = imputer.transform(test_inputs[numeric_cols])

# %%
train_inputs.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df[numeric_cols])
# Out:
# MinMaxScaler()

# %%
print('min')
list(scaler.data_min_)
# Out:
# min
# [np.float64(0.0), np.float64(0.0), np.float64(18.25), np.float64(18.8)]

# %%
print('max')
list(scaler.data_max_)
# Out:
# max
# [np.float64(1.0), np.float64(72.0), np.float64(118.75), np.float64(8684.8)]

# %%
train_inputs[numeric_cols] = scaler.transform(train_inputs[numeric_cols])
val_inputs[numeric_cols] = scaler.transform(val_inputs[numeric_cols])
test_inputs[numeric_cols] = scaler.transform(test_inputs[numeric_cols])

# %%
train_inputs[numeric_cols].describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    4507.000000  4507.000000     4507.000000   4507.000000
# mean        0.163523     0.451384        0.464471      0.262743
# std         0.369884     0.339678        0.298691      0.260601
# min         0.000000     0.000000        0.001493      0.000000
# 25%         0.000000     0.125000        0.180100      0.045883
# 50%         0.000000     0.402778        0.520896      0.161314
# 75%         0.000000     0.777778        0.712935      0.436138
# max         1.000000     1.000000        0.998507      0.989568

# %%
df[categorical_cols].nunique()
# Out:
# gender              2
# Partner             2
# Dependents          2
# PhoneService        2
# MultipleLines       3
# InternetService     3
# OnlineSecurity      3
# OnlineBackup        3
# DeviceProtection    3
# TechSupport         3
# StreamingTV         3
# StreamingMovies     3
# Contract            3
# PaperlessBilling    2
# PaymentMethod       4
# dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
encode = OneHotEncoder(sparse_output=False,handle_unknown='ignore')

# %%
encode.fit(df[categorical_cols])
# Out:
# OneHotEncoder(handle_unknown='ignore', sparse_output=False)

# %%
encode.categories_
# Out:
# [array(['Female', 'Male'], dtype=object),
#  array(['No', 'Yes'], dtype=object),
#  array(['No', 'Yes'], dtype=object),
#  array(['No', 'Yes'], dtype=object),
#  array(['No', 'No phone service', 'Yes'], dtype=object),
#  array(['DSL', 'Fiber optic', 'No'], dtype=object),
#  array(['No', 'No internet service', 'Yes'], dtype=object),
#  array(['No', 'No internet service', 'Yes'], dtype=object),
#  array(['No', 'No internet service', 'Yes'], dtype=object),
#  array(['No', 'No internet service', 'Yes'], dtype=object),
#  array(['No', 'No internet service', 'Yes'], dtype=object),
#  array(['No', 'No internet service', 'Yes'], dtype=object),
#  array(['Month-to-month', 'One year', 'Two year'], dtype=object),
#  array(['No', 'Yes'], dtype=object),
#  array(['Bank transfer (automatic)', 'Credit card (automatic)',
#         'Electronic check', 'Mailed check'], dtype=object)]

# %%
encode_col = list(encode.get_feature_names_out(categorical_cols))
print(encode_col)
# Out:
# ['gender_Female', 'gender_Male', 'Partner_No', 'Partner_Yes', 'Dependents_No', 'Dependents_Yes', 'PhoneService_No', 'PhoneService_Yes', 'MultipleLines_No', 'MultipleLines_No phone service', 'MultipleLines_Yes', 'InternetService_DSL', 'InternetService_Fiber optic', 'InternetService_No', 'OnlineSecurity_No', 'OnlineSecurity_No internet service', 'OnlineSecurity_Yes', 'OnlineBackup_No', 'OnlineBackup_No internet service', 'OnlineBackup_Yes', 'DeviceProtection_No', 'DeviceProtection_No internet service', 'DeviceProtection_Yes', 'TechSupport_No', 'TechSupport_No internet service', 'TechSupport_Yes', 'StreamingTV_No', 'StreamingTV_No internet service', 'StreamingTV_Yes', 'StreamingMovies_No', 'StreamingMovies_No internet service', 'StreamingMovies_Yes', 'Contract_Month-to-month', 'Contract_One year', 'Contract_Two year', 'PaperlessBilling_No', 'PaperlessBilling_Yes', 'PaymentMethod_Bank transfer (automatic)', 'PaymentMethod_Credit card (automatic)', 'PaymentMethod_Electronic check', 'Payme
# ...

# %%
train_inputs[encode_col] = encode.transform(train_inputs[categorical_cols])
val_inputs[encode_col] = encode.transform(val_inputs[categorical_cols])
test_inputs[encode_col] = encode.transform(test_inputs[categorical_cols])

# %%
train_inputs[encode_col]
# Out:
#       gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  \
# 3514            0.0          1.0         0.0          1.0            0.0
# 1376            0.0          1.0         1.0          0.0            1.0
# 3980            0.0          1.0         1.0          0.0            1.0
# 4697            0.0          1.0         0.0          1.0            1.0
# 6455            0.0          1.0         0.0          1.0            1.0
# ...             ...          ...         ...          ...            ...
# 1318            0.0          1.0         1.0          0.0            1.0
# 2589            0.0          1.0         1.0          0.0            1.0
# 1092            0.0          1.0         0.0          1.0            1.0
# 5569            1.0          0.0         0.0          1.0            1.0
# 5920            1.0          0.0         1.0          0.0            1.0
#
#       Dependents_Yes  PhoneService_No  PhoneService_Yes  MultipleLines_No  \
# ...

# %%
train_inputs
# Out:
#       gender  SeniorCitizen Partner Dependents    tenure PhoneService  \
# 3514    Male            0.0     Yes        Yes  0.833333          Yes
# 1376    Male            0.0      No         No  0.069444          Yes
# 3980    Male            0.0      No         No  0.388889          Yes
# 4697    Male            0.0     Yes         No  1.000000          Yes
# 6455    Male            0.0     Yes         No  0.819444           No
# ...      ...            ...     ...        ...       ...          ...
# 1318    Male            0.0      No         No  0.111111          Yes
# 2589    Male            1.0      No         No  0.041667          Yes
# 1092    Male            0.0     Yes         No  0.972222          Yes
# 5569  Female            1.0     Yes         No  0.041667          Yes
# 5920  Female            1.0      No         No  0.361111          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %% [markdown]
# Modeling

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver='lbfgs', max_iter=1000)

# %%
model.fit(train_inputs[numeric_cols+encode_col],train_targets)
# Out:
# LogisticRegression(max_iter=1000)

# %%
x_train = train_inputs[numeric_cols+encode_col]
x_val = val_inputs[numeric_cols+encode_col]
x_test = test_inputs[numeric_cols+encode_col]

# %%
x_train
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 3514            0.0  0.833333        0.918905      0.757910            0.0
# 1376            0.0  0.069444        0.514925      0.037918            0.0
# 3980            0.0  0.388889        0.870149      0.341646            0.0
# 4697            0.0  1.000000        0.760199      0.776431            0.0
# 6455            0.0  0.819444        0.259204      0.305556            0.0
# ...             ...       ...             ...           ...            ...
# 1318            0.0  0.111111        0.482090      0.064643            0.0
# 2589            1.0  0.041667        0.575124      0.024579            0.0
# 1092            0.0  0.972222        0.464677      0.519784            0.0
# 5569            1.0  0.041667        0.653234      0.028687            1.0
# 5920            1.0  0.361111        0.602488      0.229321            1.0
#
# ...

# %%
train_pred = model.predict(x_train)

# %%
train_pred
# Out:
# array(['No', 'No', 'Yes', ..., 'No', 'Yes', 'Yes'],
#       shape=(4507,), dtype=object)

# %%
train_targets
# Out:
# 3514     No
# 1376    Yes
# 3980    Yes
# 4697     No
# 6455     No
#        ...
# 1318     No
# 2589    Yes
# 1092     No
# 5569    Yes
# 5920     No
# Name: Churn, Length: 4507, dtype: object

# %%
train_probs = model.predict_proba(x_train)
train_probs
# Out:
# array([[0.91846122, 0.08153878],
#        [0.66066605, 0.33933395],
#        [0.36203722, 0.63796278],
#        ...,
#        [0.99468715, 0.00531285],
#        [0.39637946, 0.60362054],
#        [0.38783347, 0.61216653]], shape=(4507, 2))

# %%
print(model.coef_.tolist())
# Out:
# [[0.22604420372293174, -2.7787536173728595, -0.10980732283842341, 0.7930759206683553, -0.07901957072555421, -0.05943698208381493, -0.08093454906308686, -0.05752200374628392, -0.023480679487430135, -0.11497587332194054, 0.02114833763357443, -0.1596048904429518, -0.2342469902438296, 0.02114833763357443, 0.07464209980088479, -0.38097240594881415, 0.39846480517686766, -0.15594895203742046, 0.20108298155104323, -0.15594895203742046, -0.18359058232299466, 0.1038763085656998, -0.15594895203742046, -0.08638390933765085, -0.01818452889725905, -0.15594895203742046, 0.03567692812530694, 0.18973020836079116, -0.15594895203742046, -0.17223780913273584, -0.07204042618313064, -0.15594895203742046, 0.08953282541118276, -0.14729736688225847, -0.15594895203742046, 0.16478976611030952, 0.6885903954694842, -0.0621733165348254, -0.764873631744031, -0.20879775651356614, 0.0703412037041817, -0.12584412901140235, -0.14487020964942665, 0.20100476567376335, -0.06874697982230321]]

# %%
print(model.intercept_)
# Out:
# [-0.23225771]

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(train_targets,train_pred)
# Out:
# 0.8027512757932106

# %%
confusion_matrix(train_targets,train_pred,normalize='true')
# Out:
# array([[0.89697885, 0.10302115],
#        [0.45781119, 0.54218881]])

# %%
import plotly.figure_factory as ff

def predict_and_plot(x_test, y_test):
    y_pred = model.predict(x_test)
    cm = confusion_matrix(y_test, y_pred)
    
    fig = ff.create_annotated_heatmap(
        z=cm,
        x=["Predicted No", "Predicted Yes"],
        y=["Actual No", "Actual Yes"],
        colorscale='Oranges'
    )
    fig.update_layout(title="Confusion Matrix")
    
    return fig

# %%
import seaborn as sns
predict_and_plot(x_train,train_targets)

# %%
predict_and_plot(x_val,val_targets)

# %%
import plotly.express as px
import plotly.io as pio
from IPython.display import Image, display
fig = predict_and_plot(x_test,test_targets)
fig.write_image("Confusion martix.png")
display(Image("Confusion martix.png"))
